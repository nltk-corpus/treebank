# %%
# !pip install transformers torch
from transformers import pipeline
re = pipeline(
    "text-generation",
    model="Babelscape/rebel-large"
)
text = "Sundar Pichai is the CEO of Google. Google is based in the United States."
output = re(text, max_length=100)
print(output[0]['generated_text'])

# !pip install transformers torch
from transformers import pipeline
ner = pipeline(
    "ner",
    model="dslim/bert-base-NER",
    aggregation_strategy="simple"
)
text = "I met Priyanka Chopra on 12th November 2001 in India."
output = ner(text)
print(output)
